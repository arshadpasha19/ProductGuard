# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("ewg_data.csv")
df
# Out:
#                             Product Name  Product Score Cancer Concern  \
# 0                                  WATER              1            LOW
# 1                              FRAGRANCE              8            LOW
# 2                               GLYCERIN              1            LOW
# 3                         PHENOXYETHANOL              2            LOW
# 4                            IRON OXIDES              3            LOW
# ...                                  ...            ...            ...
# 5995             BUTYLENE GLYCOL LAURATE              1            LOW
# 5996                 C12-14 SEC-PARETH-5              1            LOW
# 5997                     C14-15 ALCOHOLS              1            LOW
# 5998  CARYA ILLINOENSIS (PECAN) SEED OIL              1            LOW
# 5999                    CEDRUS ATLANTICA              1            LOW
#
#      Allergies & Immunotoxicity Developmental and Reproductive Toxicity  \
# ...

# %%
product1 = ["SODIUM PALMATE", "SODIUM PALM KERNELATE", "WATER", "TALC", "GLYCERIN", "PERFUME", "SODIUM CHLORIDE", "TITANIUM DIOXIDE", 
            "LAURIC ACID", "PEG-8", "POLYSORBATE 20", "TETRASODIUM ETIDRONATE", "MILK LIPIDS", "TETRASODIUM EDTA", "SERICIN", 
            "ROSA GALLICA FLOWER EXTRACT", "JASMINUM OFFICINALE (JASMINE) FLOWER EXTRACT", "PRUNUS AMYGDALUS DULCIS (SWEET ALMOND) OIL", 
            "NELUMBIUM SPECIOSUM FLOWER OIL", "MENTHA ARVENSIS LEAF OIL", "CYMBOPOGON MARTINI OIL", "PEG-40 HYDROGENATED CASTOR OIL", 
            "METHYLCHLOROISOTHIAZOLINONE", "METHYLISOTHIAZOLINONE", "ALPHA-ISOMETHYL IONONE", "BENZYL SALICYLATE", 
            "BUTYLPHENYL METHYLPROPIONAL", "EUGENOL", "GERANIOL", "HEXYL CINNAMAL"]

# %%
len(product1)
# Out:
# 30

# %%
product2 = ["SODIUM PALMATE", "SODIUM PALM KERNELATE", "WATER", "PERFUME", "GLYCERIN", "SODIUM CHLORIDE", "SORBITOL", 
            "TITANIUM DIOXIDE", "TETRASODIUM ETIDRONATE", "TETRASODIUM EDTA", "TEA TREE (MELALEUCA ALTERNAFOLIA) OIL", 
            "LIME (CITRUS AURANTIFOLIA) EXTRACT", "AMYLCINNAMYL ALCOHOL", "AMYL CINNAMAL", "BENZYL BENZOATE", "CITRAL", 
            "BUTYLPHENYL METHYLPROPINAL", "CITRONELLOL", "GERANIOL", "HEXYL CINNAMAL", "ISOEUGENOL", "LIMONENE", "LINALOOL", 
            "METHYLCHLOROISOTHIAZOLINONE", "METHYLISOTHIAZOLINONE"]

# %%
len(product2)
# Out:
# 25

# %%
def filter_ingredients(ingredients):
    # Filter rows based on whether the 'IngredientName' is in the ingredient list
    filtered_dataset = df[df['Product Name'].isin(ingredients)]
    
    # Reset the index of the filtered dataset
    filtered_dataset.reset_index(drop=True, inplace=True)
    
    return filtered_dataset


# Call the function to filter the dataset
ingredients1 = filter_ingredients(product1)
ingredients2 = filter_ingredients(product2)

# %%
ingredients1
# Out:
#                                   Product Name  Product Score Cancer Concern  \
# 0                                        WATER              1            LOW
# 1                                     GLYCERIN              1            LOW
# 2                             TITANIUM DIOXIDE              1       MODERATE
# 3                              SODIUM CHLORIDE              1            LOW
# 4                                         TALC              5           HIGH
# 5                             TETRASODIUM EDTA              2            LOW
# 6                                     GERANIOL              3            LOW
# 7                               HEXYL CINNAMAL              3            LOW
# 8                        METHYLISOTHIAZOLINONE              7            LOW
# 9                            BENZYL SALICYLATE              3            LOW
# 10                 METHYLCHLOROISOTHIAZOLINONE              6            LOW
# ...

# %%
ingredients2
# Out:
#                    Product Name  Product Score Cancer Concern  \
# 0                         WATER              1            LOW
# 1                      GLYCERIN              1            LOW
# 2              TITANIUM DIOXIDE              1       MODERATE
# 3               SODIUM CHLORIDE              1            LOW
# 4                      LINALOOL              3            LOW
# 5                      LIMONENE              4            LOW
# 6              TETRASODIUM EDTA              2            LOW
# 7                   CITRONELLOL              3            LOW
# 8                      GERANIOL              3            LOW
# 9                HEXYL CINNAMAL              3            LOW
# 10        METHYLISOTHIAZOLINONE              7            LOW
# 11  METHYLCHLOROISOTHIAZOLINONE              6            LOW
# 12                       CITRAL              3            LOW
# 13              BENZYL BENZOATE              4            LOW
# ...

# %%
# Create a new column 'Safety Level' based on the specified ranges
ingredients1['Safety Level'] = pd.cut(ingredients1['Product Score'], bins=[0, 2, 6, 10], labels=['Safe', 'Moderate', 'Harmful'], right=False)

# Count the occurrences of each safety level
safety_counts = ingredients1['Safety Level'].value_counts()

# Convert the index to strings for concatenation
safety_counts.index = safety_counts.index.astype(str)

# Pie chart
colors = ['#33CC33', '#F4D03F', '#CB4335']
plt.figure(figsize=(8, 8))
plt.pie(safety_counts, labels=safety_counts.index + ' (' + safety_counts.astype(str) + ')', autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Safety Level Distribution of Ingredients - Product 1')
plt.show()
# Out:
# C:\Users\SAJJAD-PC\AppData\Local\Temp\ipykernel_20800\1783040918.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingredients1['Safety Level'] = pd.cut(ingredients1['Product Score'], bins=[0, 2, 6, 10], labels=['Safe', 'Moderate', 'Harmful'], right=False)

# %%
# Create a new column 'Safety Level' based on the specified ranges
ingredients2['Safety Level'] = pd.cut(ingredients2['Product Score'], bins=[0, 2, 6, 10], labels=['Safe', 'Moderate', 'Harmful'], right=False)

# Count the occurrences of each safety level
safety_counts = ingredients2['Safety Level'].value_counts()

# Convert the index to strings for concatenation
safety_counts.index = safety_counts.index.astype(str)

# Pie chart
colors = ['#33CC33', '#F4D03F', '#CB4335']
plt.figure(figsize=(8, 8))
plt.pie(safety_counts, labels=safety_counts.index + ' (' + safety_counts.astype(str) + ')', autopct='%1.1f%%', colors=colors, startangle=140)
plt.title('Safety Level Distribution of Ingredients - product 2')
plt.show()
# Out:
# C:\Users\SAJJAD-PC\AppData\Local\Temp\ipykernel_20800\2355218703.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingredients2['Safety Level'] = pd.cut(ingredients2['Product Score'], bins=[0, 2, 6, 10], labels=['Safe', 'Moderate', 'Harmful'], right=False)

# %%
def calculate_normalized_safety_score(product):
    total_score = 0
    num_ingredients = len(product)
    for ingredient in product:
        # Calculate score for concerns
        score = 0

        # Include the product score in the calculation
        product_score = ingredient.get("Product Score")
        score += product_score

        # Add points for safety concerns
        score += get_concern_score(ingredient.get("Allergies & Immunotoxicity"))
        score += get_concern_score(ingredient.get("Cancer Concern"))
        score += get_concern_score(ingredient.get("Developmental and Reproductive Toxicity"))
        score += get_concern_score(ingredient.get("Use Restrictions"))

        total_score += score

    # Calculate normalized score per ingredient
    normalized_score = total_score / num_ingredients
    
    return normalized_score


def get_concern_score(concern):
    if concern == "MODERATE":
        return 1
    elif concern == "HIGH":
        return 2
    else:
        return 0

# %%
product1=[{"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate), Non-reproductive organ system toxicity (moderate), Irritation (skin, eyes, or lungs) (high), and Occupational hazards (high)", "Product Name": "PHENOXYETHANOL", "Product Score": 2, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate)", "Product Name": "CITRIC ACID", "Product Score": 1, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "MODERATE", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high) and Contamination concerns (high)", "Product Name": "COCAMIDOPROPYL BETAINE", "Product Score": 1, "Use Restrictions": "HIGH"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Non-reproductive organ system toxicity (moderate)", "Product Name": "GUAR HYDROXYPROPYLTRIMONIUM CHLORIDE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high), Neurotoxicity (low), Endocrine disruption (low), Non-reproductive organ system toxicity (moderate), and Irritation (skin, eyes, or lungs) (low)", "Product Name": "CETRIMONIUM CHLORIDE", "Product Score": 7, "Use Restrictions": "HIGH"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Multiple, additive exposure sources (low)", "Product Name": "GLYCOL DISTEARATE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (low), Endocrine disruption (low), and Irritation (skin, eyes, or lungs) (low)", "Product Name": "COCO-GLUCOSIDE", "Product Score": 2, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (low)", "Product Name": "SODIUM COCOYL ISETHIONATE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high), Irritation (skin, eyes, or lungs) (low), and Contamination concerns (high)", "Product Name": "COCAMIDE MEA", "Product Score": 1, "Use Restrictions": "HIGH"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Irritation (skin, eyes, or lungs) (moderate)", "Product Name": "GLYCERYL OLEATE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Persistence and bioaccumulation (moderate)", "Product Name": "CAFFEINE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "MODERATE", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high)", "Product Name": "STEARAMIDOPROPYL DIMETHYLAMINE", "Product Score": 2, "Use Restrictions": "HIGH"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Enhanced skin absorption, Use restrictions (moderate), and Contamination concerns (high)", "Product Name": "SODIUM LAUROYL SARCOSINATE", "Product Score": 1, "Use Restrictions": "MODERATE"}]

# %%
product2=[{"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "WATER", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate)", "Product Name": "GLYCERIN", "Product Score": 1, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "MODERATE", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Non-reproductive organ system toxicity (moderate) and Occupational hazards (high)", "Product Name": "TITANIUM DIOXIDE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "SODIUM CHLORIDE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "LINALOOL", "Product Score": 3, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate), Persistence and bioaccumulation (moderate), Ecotoxicology (low), and Irritation (skin, eyes, or lungs) (high)", "Product Name": "LIMONENE", "Product Score": 4, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Enhanced skin absorption, Non-reproductive organ system toxicity (moderate), Irritation (skin, eyes, or lungs) (high), and Occupational hazards (high)", "Product Name": "TETRASODIUM EDTA", "Product Score": 2, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate)", "Product Name": "CITRONELLOL", "Product Score": 3, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate)", "Product Name": "GERANIOL", "Product Score": 3, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "HEXYL CINNAMAL", "Product Score": 3, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate) and Irritation (skin, eyes, or lungs) (high)", "Product Name": "CITRAL", "Product Score": 3, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate), Endocrine disruption (low), Ecotoxicology (low), and Occupational hazards (high)", "Product Name": "BENZYL BENZOATE", "Product Score": 4, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Enhanced skin absorption, Endocrine disruption (low), Non-reproductive organ system toxicity (moderate), and Irritation (skin, eyes, or lungs) (moderate)", "Product Name": "MELALEUCA ALTERNIFOLIA (TEA TREE) LEAF OIL", "Product Score": 6, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "SODIUM PALMATE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "null", "Product Name": "SODIUM PALM KERNELATE", "Product Score": 1, "Use Restrictions": "LOW"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high) and Irritation (skin, eyes, or lungs) (low)", "Product Name": "TETRASODIUM ETIDRONATE", "Product Score": 1, "Use Restrictions": "HIGH"}, {"Allergies & Immunotoxicity": "HIGH", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (moderate)", "Product Name": "ISOEUGENOL", "Product Score": 3, "Use Restrictions": "MODERATE"}, {"Allergies & Immunotoxicity": "LOW", "Cancer Concern": "LOW", "Developmental and Reproductive Toxicity": "LOW", "Other Concerns": "Use restrictions (high), Non-reproductive organ system toxicity (low), and Irritation (skin, eyes, or lungs) (low)", "Product Name": "CITRUS AURANTIFOLIA (LIME) FRUIT EXTRACT", "Product Score": 1, "Use Restrictions": "HIGH"}]

# %%
# Example usage:
product1_normalized_score = calculate_normalized_safety_score(product1)
product2_normalized_score = calculate_normalized_safety_score(product2)

print("Normalized Product 1 Safety Score:", product1_normalized_score)
print("Normalized Product 2 Safety Score:", product2_normalized_score)
# Out:
# Normalized Product 1 Safety Score: 2.8461538461538463
# Normalized Product 2 Safety Score: 4.0
